# %%
import pandas as pd
import os
import shutil

# Paths
CSV_PATH = "D:\Project DS.AIML\Medical-Imaging-Quality-Assurance-System\data"  # choose correct file
IMAGES_DIR = "data/images/"
OUTPUT_DIR = "data/processed/"

# %%
if not os.path.exists(CSV_PATH):
    raise FileNotFoundError(f"CSV file not found at {CSV_PATH}")

print(f"Loading CSV from {CSV_PATH}...")
df = pd.read_csv(CSV_PATH)

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 if not os.path.exists(CSV_PATH):
# ----> 2     raise FileNotFoundError(f"CSV file not found at {CSV_PATH}")
#       4 print(f"Loading CSV from {CSV_PATH}...")
#       5 df = pd.read_csv(CSV_PATH)
#
# FileNotFoundError: CSV file not found at data/Data_Entry_2017_v2020.csv
